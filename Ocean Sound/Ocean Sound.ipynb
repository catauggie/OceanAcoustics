# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

def ocean_sound(T, S, z):

    #T, S, z = params 
    c = 1449.2 + 4.6*T - 0.055*T**2 + 0.00029*T**3+(1.34 - 0.010*T)*(S - 35) + 0.016*z
        
    return c

fig = plt.figure()
ax = fig.gca(projection="3d")  # get current axis

T = np.arange(32, 25, -0.01)
z = np.arange(0, 1000, 1)
S=34.5
T, z = np.meshgrid(T, z)
Z = ocean_sound(T, S, z)

surf = ax.plot_surface(T, z, Z)
ax.set_xlabel("Температура, $^\circ C$")
ax.set_ylabel("Глубина, м")
ax.set_zlabel("Скорость звука, м/с")
ax.set_title(f"Зависимость скорости звука в океане при солености S={S}")
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_9264\3064126648.py:13: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")  # get current axis

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

def ocean_sound(T, S, z):

    #T, S, z = params 
    c = 1449.2 + 4.6*T - 0.055*T**2 + 0.00029*T**3+(1.34 - 0.010*T)*(S - 35) + 0.016*z
        
    return c

fig = plt.figure()
ax = fig.gca(projection="3d")  # get current axis

T = np.arange(32, 25, -0.01)
S = np.arange(5, 35, 1) 
T, S = np.meshgrid(T, S)
z=500
Z = ocean_sound(T, S, z)

surf = ax.plot_surface(T, S, Z)
ax.set_xlabel("Температура, $^\circ C$")
ax.set_ylabel("Соленость")
ax.set_zlabel("Скорость звука, м/с")
ax.set_title(f"Зависимость скорости звука в океане на глубине z={z} м")
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_9264\159623873.py:13: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")  # get current axis

# %%
1.3632E-7
# Out:
# 1.3632e-07

# %%
C00=1402.388
A02=7.166E-5
C01=5.03830
A03=2.008E-6
C00=1402.388
A02=7.166E-5
C01=5.03830
A03=2.008E-6
C02=-5.81090E-2
A04=-3.21E-8
C03=3.3432E-4
A10=9.4742E-5
C04=-1.47797E-6
A11=-1.2583E-5
C05=3.1419E-9
A12=-6.4928E-8
C10=0.153563
A13=1.0515E-8
C11=6.8999E-4
A14=-2.0142E-10
C12=-8.1829E-6
A20=-3.9064E-7
C13=1.3632E-7
A21=9.1061E-9
C14=-6.1260E-10
A22=-1.6009E-10
C20=3.1260E-5
A23=7.994E-12
C21=-1.7111E-6
A30=1.100E-10
C22=2.5986E-8
A31=6.651E-12
C23=-2.5353E-10
A32=-3.391E-13
C24=1.0415E-12
B00=-1.922E-2
C30=-9.7729E-9
B01=-4.42E-5
C31=3.8513E-10
B10=7.3637E-5
C32=-2.3654E-12
B11=1.7950E-7
A00=1.389
D00=1.727E-3
A01=-1.262E-2
D10=-7.9836E-6

# %%
def C_w(T,P):
    C_w = (C00 + C01*T + C02*T**2 + C03*T**3 + C04*T**4 + C05*T**5) +(C10 + C11*T + C12*T**2 + C13*T**3 + C14*T**4)*P +(C20 +C21*T +C22*T**2 + C23*T**3 + C24*T**4)*P**2 +(C30 + C31*T + C32*T**2)*P**3
    return C_w

# %%
def A(T,P):
    A = (A00 + A01*T + A02*T**2 + A03*T**3 + A04*T**4) +(A10 + A11*T + A12*T**2 + A13*T**3 + A14*T**4)*P +(A20 + A21*T + A22*T**2 + A23*T**3)*P**2 +(A30 + A31*T + A32*T**2)*P**3
    return A

# %%
def B(T,P):
    B = B00 + B01*T + (B10 + B11*T)*P
    return B

# %%
def D(T,P):
    D = D00 + D10*P
    return D

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")  # get current axis

T = np.arange(0, 40, 0.1)
P = np.arange(0, 1000, 1) 
T, P = np.meshgrid(T, P)
Z = C_w(T,P)

surf = ax.plot_surface(T, P, Z)
ax.set_xlabel("Температура, $^\circ C$")
ax.set_ylabel("Давление, бар")
ax.set_zlabel("$C_w$")
ax.set_title(f"Зависимость коэффициента $C_w$ от температуры и давления")
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_9264\230318280.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")  # get current axis

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")  # get current axis

T = np.arange(0, 40, 0.1)
P = np.arange(0, 1000, 1) 
T, P = np.meshgrid(T, P)
Z = A(T,P)

surf = ax.plot_surface(T, P, Z)
ax.set_xlabel("Температура, $^\circ C$")
ax.set_ylabel("Давление, бар")
ax.set_zlabel("$A$")
ax.set_title(f"Зависимость коэффициента A от температуры и давления")
plt.savefig("Зависимость коэффициента A от температуры и давления")
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_9264\4075069778.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")  # get current axis

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")  # get current axis

T = np.arange(0, 40, 0.1)
P = np.arange(0, 1000, 1) 
T, P = np.meshgrid(T, P)
Z = B(T,P)

surf = ax.plot_surface(T, P, Z)
ax.set_xlabel("Температура, К")
ax.set_ylabel("Давление, бар")
ax.set_zlabel("$B$")
ax.set_title(f"Зависимость коэффициента B от температуры и давления")
plt.savefig(f"Зависимость коэффициента B от температуры и давления")
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_9264\1258372573.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")  # get current axis

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")  # get current axis

T = np.arange(0, 40, 0.1)
P = np.arange(0, 1000, 1) 
T, P = np.meshgrid(T, P)
Z = D(T,P)

surf = ax.plot_surface(T, P, Z)
ax.set_xlabel("Температура, $^\circ C$")
ax.set_ylabel("Давление, бар")
ax.set_zlabel("$D$")
ax.set_title(f"Зависимость коэффициента D от температуры и давления")
plt.savefig(f"Зависимость коэффициента D от температуры и давления")
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_9264\1089898788.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")  # get current axis

# %%
def c(S,T,P):
    c = C_w(T,P) + A(T,P)*S + B(T,P)*S*1.5 + D(T,P)*S**2
    return c

# %%
fig = plt.figure()
ax = fig.gca(projection="3d")  # get current axis

T = np.arange(0, 40, 0.1)
P = np.arange(0, 1000, 1) 
T, P = np.meshgrid(T, P)
S=30
Z = c(S,T,P)

surf = ax.plot_surface(T, P, Z)
ax.set_xlabel("Температура, $^\circ C$")
ax.set_ylabel("Давление, бар")
ax.set_zlabel("Скорость звука, м/с")
ax.set_title(f"Зависимость скорости звука в океане при солености S={S}")
plt.savefig(f"Зависимость скорости звука в океане при солености S={S}")
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_9264\2827240499.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")  # get current axis
